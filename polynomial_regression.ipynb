# %% [markdown]
# <a href="https://colab.research.google.com/github/SmartDogy/ML_Playground/blob/main/polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/Ice_cream selling data.csv')

# %%
dataset.head()
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %%
X = dataset.iloc[:, 0].values.reshape(-1, 1)
Y = dataset.iloc[:, 1].values.reshape(-1, 1)

# %%
plt.scatter(X, Y)
plt.xlabel('Temperauture')
plt.ylabel('Unit sold')
# Out:
# Text(0, 0.5, 'Unit sold')

# %%
x_test, x_train, y_test, y_train = train_test_split(X, Y, test_size = 0.2, random_state = 2)

# %%
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x_train)

# %%
lr = LinearRegression()

# %%
lr.fit(x_poly, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y)
x_sorted = np.sort(X, axis=0)
X_poly_sorted = poly.transform(x_sorted)
Y_pred = model.predict(X_poly_sorted)
plt.plot(x_sorted, Y_pred, color='red')
plt.xlabel('Temperauture')
plt.ylabel('Unit sold')
# Out:
# Text(0, 0.5, 'Unit sold')

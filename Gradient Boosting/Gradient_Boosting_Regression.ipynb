# %% [markdown]
# <a href="https://colab.research.google.com/github/SmartDogy/ML_Playground/blob/main/Gradient_Boosting_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression

# %%
X, Y = make_regression(n_samples=200, n_features=2, n_informative=2, n_targets=1, noise=20)

# %%
dataset = pd.DataFrame(data=X)

# %%
dataset.head()
# Out:
#           0         1
# 0 -0.436795 -1.430052
# 1 -0.750131  0.042748
# 2  0.276033  1.164449
# 3  1.248537  0.412040
# 4 -0.563234  1.394341

# %%
dataset['Target'] = Y

# %%
dataset.head()
# Out:
#           0         1      Target
# 0 -0.436795 -1.430052 -119.382909
# 1 -0.750131  0.042748  -36.406286
# 2  0.276033  1.164449  107.608182
# 3  1.248537  0.412040   27.672908
# 4 -0.563234  1.394341   73.912936

# %%
plt.scatter(dataset[0], dataset[1], c=Y, cmap='autumn', s=100, edgecolors='black')

# %%
X = dataset.iloc[:,[0,1]].values
Y = dataset.iloc[:,-1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
clf = GradientBoostingRegressor()
clf.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

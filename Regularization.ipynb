# %% [markdown]
# <a href="https://colab.research.google.com/github/SmartDogy/ML_Playground/blob/main/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X, Y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=30)

# %%
plt.scatter(X,Y)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
clf = LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(r2_score(y_test, clf.predict(x_test)))
# Out:
# 0.6392938737817029

# %%
clf2 = Ridge(alpha=10)
clf2.fit(x_train, y_train)
# Out:
# Ridge(alpha=10)

# %%
print(r2_score(y_test, clf2.predict(x_test)))
# Out:
# 0.6333583072503903
